# %%
import pandas as pd
df1 = pd.read_csv("E:/Data Science class/Datasets/student.csv")
df2 = pd.read_csv("E:/Data Science class/Datasets/student.csv")

# %%
df1.head()
# Out:
#    Student_id  Age  Gender      Grade Employed
# 0           1   19    Male  1st Class      yes
# 1           2   20  Female  2nd Class       no
# 2           3   18    Male  1st Class       no
# 3           4   21  Female  2nd Class       no
# 4           5   19    Male  1st Class       no

# %%
df2.head()
# Out:
#    Student_id  Age  Gender      Grade Employed
# 0           1   19    Male  1st Class      yes
# 1           2   20  Female  2nd Class       no
# 2           3   18    Male  1st Class       no
# 3           4   21  Female  2nd Class       no
# 4           5   19    Male  1st Class       no

# %%
df = pd.merge(df1, df2, on = 'Student_id')

# %%
df.head(10)
# Out:
#    Student_id  Age_x Gender_x    Grade_x Employed_x  Age_y Gender_y  \
# 0           1     19     Male  1st Class        yes     19     Male
# 1           2     20   Female  2nd Class         no     20   Female
# 2           3     18     Male  1st Class         no     18     Male
# 3           4     21   Female  2nd Class         no     21   Female
# 4           5     19     Male  1st Class         no     19     Male
# 5           6     20     Male  2nd Class        yes     20     Male
# 6           7     19   Female  3rd Class        yes     19   Female
# 7           8     21     Male  3rd Class        yes     21     Male
# 8           9     22   Female  3rd Class        yes     22   Female
# 9          10     21     Male  1st Class         no     21     Male
#
#      Grade_y Employed_y
# 0  1st Class        yes
# 1  2nd Class         no
# 2  1st Class         no
# 3  2nd Class         no
# 4  1st Class         no
# 5  2nd Class        yes
# 6  3rd Class        yes
# ...
