# %%
import pandas as pd
A = pd.read_csv("E:/Data Science class/Datasets/ts.csv",names=["year","passengers"])

# %%
A.head()
# Out:
#       year  passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
A.year = pd.to_datetime(A.year,format="%Y-%m")

# %%
A.index=A.year

# %%
A = A.drop(labels="year",axis=1)

# %%
A.head(2)
# Out:
#             passengers
# year
# 1949-01-01         112
# 1949-02-01         118

# %%
import seaborn as sb
sb.distplot(A)

# %%
import matplotlib.pyplot as plt
plt.plot(A)

# %%
sb.boxplot(A.index.year,A.passengers)

# %%
import statsmodels.api as sm
sm.tsa.seasonal_decompose(A).plot()
plt.show()
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
rm = A.rolling(window=12).mean() #rolling mean
rstd = A.rolling(window=12).std() #rolling standard deviatation

# %%
rm
# Out:
#             passengers
# year
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01  126.666667
# 1950-01-01  126.916667
# 1950-02-01  127.583333
# 1950-03-01  128.333333
# 1950-04-01  128.833333
# 1950-05-01  129.166667
# 1950-06-01  130.333333
# 1950-07-01  132.166667
# 1950-08-01  134.000000
# 1950-09-01  135.833333
# 1950-10-01  137.000000
# 1950-11-01  137.833333
# 1950-12-01  139.666667
# 1951-01-01  142.166667
# 1951-02-01  144.166667
# 1951-03-01  147.250000
# 1951-04-01  149.583333
# 1951-05-01  153.500000
# 1951-06-01  155.916667
# ...                ...
# 1958-07-01  376.333333
# 1958-08-01  379.500000
# 1958-09-01  379.500000
# 1958-10-01  380.500000
# 1958-11-01  380.916667
# 1958-12-01  381.000000
# 1959-01-01  382.666667
# ...

# %%
rstd
# Out:
#             passengers
# year
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01   13.720147
# 1950-01-01   13.453342
# 1950-02-01   13.166475
# 1950-03-01   13.686977
# 1950-04-01   13.822467
# 1950-05-01   13.663710
# 1950-06-01   14.760718
# 1950-07-01   18.135016
# 1950-08-01   20.797727
# 1950-09-01   21.928949
# 1950-10-01   21.315807
# 1950-11-01   20.067311
# 1950-12-01   19.070841
# 1951-01-01   17.439940
# 1951-02-01   16.781122
# 1951-03-01   19.349066
# 1951-04-01   19.425655
# 1951-05-01   18.744696
# 1951-06-01   19.942911
# ...                ...
# 1958-07-01   59.590013
# 1958-08-01   65.557054
# 1958-09-01   65.557054
# 1958-10-01   65.106207
# 1958-11-01   64.593074
# 1958-12-01   64.530472
# 1959-01-01   63.627229
# ...

# %%
plt.plot(A)
plt.plot(rm)
plt.plot(rstd)

# %%
import numpy as np
Alog = np.log(A)

rm = Alog.rolling(window=12).mean() #rolling mean
rstd = Alog.rolling(window=12).std() #rolling standard deviatation

plt.plot(Alog)
plt.plot(rm)
plt.plot(rstd)

# %%
import numpy as np
Alog = np.log(np.log(A))

rm = Alog.rolling(window=12).mean() #rolling mean
rstd = Alog.rolling(window=12).std() #rolling standard deviatation

plt.plot(Alog)
plt.plot(rm)
plt.plot(rstd)

from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
scaledA = pd.DataFrame(ss.fit_transform(A),index=A.index,columns=A.columns)

rm = scaledA.rolling(window=12).mean() #rolling mean
rstd = scaledA.rolling(window=12).std() #rolling standard deviatation

plt.plot(scaledA)
plt.plot(rm)
#plt.plot(rstd)

# %%
from statsmodels.tsa.stattools import adfuller
q = adfuller(Alog.passengers)
pval = q[1]
pval
# Out:
# 0.22258989117061334

# %%
import numpy as np
Alog = np.log(np.log(A))

rm = Alog.rolling(window=12).mean() #rolling mean
rstd = Alog.rolling(window=12).std() #rolling standard deviatation


plt.plot(Alog)
plt.plot(rm)
plt.plot(rstd)

# %%
q = Alog-rm

# %%
import numpy as np


rm = q.rolling(window=12).mean() #rolling mean
rstd = q.rolling(window=12).std() #rolling standard deviatation

# %%
plt.plot(q)
plt.plot(rm)
plt.plot(rstd)

# %%
adfuller(q.passengers[~q.passengers.isna()])[1]
# Out:
# 0.04044134645742444

# %%
#Forecasting(MA,AR,ARIMA):

# %% [markdown]
# # short term -->
# mid term -->......./n
# long term --> 500 obs
# ma(5)
# 1-5 mean
# 5-10 mean
# 10-15 mean
#
# ts --> spikes --> smooth
